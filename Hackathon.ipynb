# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt

# %%
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
print(movies.info())
print(links.info())
print(ratings.info())
print(tags.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB
# None

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# shape of movies

movies.shape
# Out:
# (9742, 3)

# %%
# shape of ratings

ratings.shape
# Out:
# (100836, 4)

# %%
# unique ids in ratings

ratings.userId.nunique()
# Out:
# 610

# %%
#Which movie has recieved maximum number of user ratings?

df = ratings.join(movies, on = 'movieId',lsuffix='_ratings',rsuffix='_movies',how = 'inner')

# %%
temp = df[(df['title'].str.contains('Matrix', na=False)) | (df['title'].str.contains('Pulp Fiction', na=False))
| (df['title'].str.contains('Forrest Gump', na=False))| (df['title'].str.contains('Shawshank Redemption', na=False))].groupby('title').size().reset_index(name = 'count')

# %%
temp.sort_values('count')
# Out:
#                               title  count
# 3                Matrix, The (1999)      8
# 4               Pulp Fiction (1994)     14
# 0               Forrest Gump (1994)     16
# 1       Matrix Reloaded, The (2003)     16
# 2    Matrix Revolutions, The (2003)     18
# 5  Shawshank Redemption, The (1994)     38

# %%
# Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

df = tags.join(movies, on = 'movieId',lsuffix='_tags',rsuffix='_movies',how = 'inner')

# %%
df[df['movieId'] == 2571]
# Out:
#       movieId  userId  movieId_tags                 tag   timestamp  \
# 815      2571     424          2571        martial arts  1457842912
# 816      2571     424          2571              sci-fi  1457842899
# 1646     2571     474          2571  alternate universe  1137204991
# 2794     2571     537          2571          philosophy  1424141098
# 2795     2571     537          2571    post apocalyptic  1424141101
#
#       movieId_movies                                              title  \
# 815             3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 816             3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 1646            3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 2794            3439  Teenage Mutant Ninja Turtles II: The Secret of...
# 2795            3439  Teenage Mutant Ninja Turtles II: The Secret of...
#
#                        genres
# 815   Action|Children|Fantasy
# 816   Action|Children|Fantasy
# 1646  Action|Children|Fantasy
# 2794  Action|Children|Fantasy
# 2795  Action|Children|Fantasy

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies[movies['movieId'] == 2571]
# Out:
#       movieId               title                  genres
# 1939     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller

# %%
tags[tags['movieId'] == 2571]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %%
# What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
df = ratings.join(movies, on = 'movieId',lsuffix='_ratings',rsuffix='_movies',how = 'inner')

# %%
df[df['title'] == 'Terminator 2: Judgment Day (1991)']['rating'].mean()
# Out:
# 3.3846153846153846

# %%
# How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

df[df['title'] == 'Fight Club (1999)']
# Out:
#        movieId  userId  movieId_ratings  rating   timestamp  movieId_movies  \
# 54510     2226     358             2226     1.0  1339545476            2959
#
#                    title                       genres
# 54510  Fight Club (1999)  Action|Crime|Drama|Thriller

# %% [markdown]
# 🟢 IMPORTANT NOTE 1 🟢
# Now that you have a good enough understanding of the given data, apply the "Mandatory Operation" given below before solving any of the following questions.
#
# Mandatory Operations:
# 1. Group the user ratings based on movieId and apply aggregation operations like count and mean on ratings.
# 2. Apply inner join on dataframe created from movies.csv and the grouped df from step 1.
# 3. Filter only those movies which have more than 50 user ratings (i.e. > 50).
#
# Above steps will make sure that your data contains only those movies which has recieved more than 50 user ratings.

# %%
s1 = ratings.groupby(['movieId'])[['rating']].count()
s1.head()
# Out:
#          rating
# movieId
# 1           215
# 2           110
# 3            52
# 4             7
# 5            49

# %%
rat = ratings.groupby(['movieId'])[['rating']].mean()['rating']
rat
s1['avg_rating'] = rat
s1
s1.rename({'rating' : 'rating_count'},inplace=True)

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
s2 = movies.join(s1,on = 'movieId',lsuffix='_movies',rsuffix='_s1',how = 'inner')

# %%
s2
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating  avg_rating
# 0     Adventure|Animation|Children|Comedy|Fantasy     215    3.920930
# 1                      Adventure|Children|Fantasy     110    3.431818
# 2                                  Comedy|Romance      52    3.259615
# 3                            Comedy|Drama|Romance       7    2.357143
# 4                                          Comedy      49    3.071429
# ...                                           ...     ...         ...
# 9737              Action|Animation|Comedy|Fantasy       1    4.000000
# 9738                     Animation|Comedy|Fantasy       1    3.500000
# 9739                                        Drama       1    3.500000
# 9740                             Action|Animation       1    3.500000
# 9741                                       Comedy       1    4.000000
#
# [9724 rows x 5 columns]

# %%
more_50_rating = s2[s2['rating']>50]

# %%
temp = more_50_rating.join(ratings,on = 'movieId',lsuffix='more_50_rating',rsuffix='_ratings',how = 'inner')

# %%
temp = temp.groupby('title')[['rating_ratings']].mean()

# %%
temp.reset_index(inplace = True)

# %%
temp.sort_values('rating_ratings',ascending=False)
# Out:
#                                                  title  rating_ratings
# 402                Truth About Cats & Dogs, The (1996)             5.0
# 189   Harry Potter and the Order of the Phoenix (2007)             5.0
# 309                                      Psycho (1960)             5.0
# 310                                Pulp Fiction (1994)             5.0
# 183                            Grumpier Old Men (1995)             5.0
# ..                                                 ...             ...
# 248  Léon: The Professional (a.k.a. The Professiona...             0.5
# 280                        Natural Born Killers (1994)             0.5
# 44                                Batman Begins (2005)             0.5
# 312  Raiders of the Lost Ark (Indiana Jones and the...             0.5
# 88                                  Chicken Run (2000)             0.5
#
# [431 rows x 2 columns]

# %%
temp[(temp['title'] == 'Godfather, The (1972)') |
(temp['title'] == 'Shawshank Redemption, The (1994)') |
(temp['title'] == 'Jumanji (1995)') |
(temp['title'] == 'Wolf of Wall Street, The (2013)')]
# Out:
#                                 title  rating_ratings
# 169             Godfather, The (1972)             3.0
# 219                    Jumanji (1995)             4.0
# 339  Shawshank Redemption, The (1994)             5.0

# %%
# Select all the correct options which comes under top 5 popular movies based on number of user ratings.

temp = more_50_rating.join(ratings,on = 'movieId',lsuffix='_more_50_rating',rsuffix='_ratings',how = 'inner')
# temp.groupby('title')[['rating_more_50_rating']].mean().sort_values('rating_ratings').tail()
temp
# Out:
#       movieId  movieId_more_50_rating                          title  \
# 0           1                       1               Toy Story (1995)
# 1           2                       2                 Jumanji (1995)
# 2           3                       3        Grumpier Old Men (1995)
# 5           6                       6                    Heat (1995)
# 6           7                       7                 Sabrina (1995)
# ...       ...                     ...                            ...
# 7466    81845                   81845      King's Speech, The (2010)
# 7693    89745                   89745           Avengers, The (2012)
# 7767    91500                   91500        The Hunger Games (2012)
# 7768    91529                   91529  Dark Knight Rises, The (2012)
# 8063    99114                   99114        Django Unchained (2012)
#
#                                            genres  rating_more_50_rating  \
# 0     Adventure|Animation|Children|Comedy|Fantasy                    215
# 1                      Adventure|Children|Fantasy                    110
# 2                                  Comedy|Romance                     52
# 5                           Action|Crime|Thriller                    102
# 6                                  Comedy|Romance                     54
# ...                                           ...                    ...
# 7466                                        Drama                     58
# 7693                 Action|Adventure|Sci-Fi|IMAX                     69
# 7767       Action|Adventure|Drama|Sci-Fi|Thriller                     54
# 7768                  Action|Adventure|Crime|IMAX                     76
# 8063                         Action|Drama|Western                     71
#
#       avg_rating  userId  movieId_ratings  rating_ratings   timestamp
# 0       3.920930       1                3             4.0   964981247
# 1       3.431818       1                6             4.0   964982224
# 2       3.259615       1               47             5.0   964983815
# 5       3.946078       1              101             5.0   964980868
# 6       3.185185       1              110             4.0   964982176
# ...          ...     ...              ...             ...         ...
# 7466    4.043103     517            56174             3.0  1487953180
# 7693    3.869565     580            51662             5.0  1212342492
# 7767    3.435185     594               28             4.5  1108973143
# 7768    3.993421     594              367             4.0  1109036766
# 8063    3.943662     608             3032             3.5  1117506429
#
# [431 rows x 10 columns]

# %%
temp.sort_values('rating_more_50_rating',ascending=False).head()
# Out:
#       movieId  movieId_more_50_rating                             title  \
# 314       356                     356               Forrest Gump (1994)
# 277       318                     318  Shawshank Redemption, The (1994)
# 257       296                     296               Pulp Fiction (1994)
# 510       593                     593  Silence of the Lambs, The (1991)
# 1939     2571                    2571                Matrix, The (1999)
#
#                            genres  rating_more_50_rating  avg_rating  userId  \
# 314      Comedy|Drama|Romance|War                    329    4.164134       4
# 277                   Crime|Drama                    317    4.429022       4
# 257   Comedy|Crime|Drama|Thriller                    307    4.197068       3
# 510         Crime|Horror|Thriller                    279    4.161290       6
# 1939       Action|Sci-Fi|Thriller                    278    4.192446      19
#
#       movieId_ratings  rating_ratings   timestamp
# 314               919             5.0   945079521
# 277               260             5.0   945079259
# 257              7991             5.0  1306463684
# 510                62             4.0   845553660
# 1939             1625             4.0   965710871

# %%
temp[temp['genres'].str.contains('Sci-Fi')].sort_values('rating_more_50_rating',ascending=False)
# Out:
#       movieId  movieId_more_50_rating  \
# 1939     2571                    2571
# 224       260                     260
# 418       480                     480
# 507       589                     589
# 898      1196                    1196
# ...       ...                     ...
# 7767    91500                   91500
# 2029     2701                    2701
# 559       673                     673
# 144       172                     172
# 6209    45499                   45499
#
#                                                   title  \
# 1939                                 Matrix, The (1999)
# 224           Star Wars: Episode IV - A New Hope (1977)
# 418                                Jurassic Park (1993)
# 507                   Terminator 2: Judgment Day (1991)
# 898   Star Wars: Episode V - The Empire Strikes Back...
# ...                                                 ...
# 7767                            The Hunger Games (2012)
# 2029                              Wild Wild West (1999)
# 559                                    Space Jam (1996)
# 144                              Johnny Mnemonic (1995)
# 6209                       X-Men: The Last Stand (2006)
#
#                                                  genres  \
# 1939                             Action|Sci-Fi|Thriller
# 224                             Action|Adventure|Sci-Fi
# 418                    Action|Adventure|Sci-Fi|Thriller
# 507                                       Action|Sci-Fi
# 898                             Action|Adventure|Sci-Fi
# ...                                                 ...
# 7767             Action|Adventure|Drama|Sci-Fi|Thriller
# 2029                       Action|Comedy|Sci-Fi|Western
# 559   Adventure|Animation|Children|Comedy|Fantasy|Sc...
# 144                              Action|Sci-Fi|Thriller
# 6209                             Action|Sci-Fi|Thriller
#
#       rating_more_50_rating  avg_rating  userId  movieId_ratings  \
# 1939                    278    4.192446      19             1625
# 224                     251    4.231076       2           131724
# 418                     238    3.750000       4             3591
# 507                     224    3.970982       6               50
# 898                     211    4.215640      10            63113
# ...                     ...         ...     ...              ...
# 7767                     54    3.435185     594               28
# 2029                     53    2.207547      19             2243
# 559                      53    2.707547       6              261
# 144                      53    2.679245       1             2640
# 6209                     52    3.355769     300              527
#
#       rating_ratings   timestamp
# 1939             4.0   965710871
# 224              5.0  1445714851
# 418              1.0   986935199
# 507              1.0   845553381
# 898              3.5  1455302183
# ...              ...         ...
# 7767             4.5  1108973143
# 2029             2.0   965706114
# 559              4.0   845553695
# 144              4.0   964982377
# 6209             5.0  1425351444
#
# [85 rows x 10 columns]

# %% [markdown]
# 🟢 IMPORTANT NOTE 2 🟢
#
#
# You already have a subset of data containing only those movies which has recieved more than 50 user ratings
#
# .
#
# Using "links.csv", scrape the IMDB reviews of each movie with more than 50 user ratings. "README.md" file contains the required detai
#
# ls.
#
# If you are unable to write the webscraping script yourself, you can request the same by commenting LinkedIn Post.

# %% [markdown]
# # WebScraping

# %%
# We thought of giving you a gift this new year by sharing the web scraping script
# Understanding the script before using is always appreciated
# We left few blanks in the script for your exploration
# Make sure to replace FILL_IN_THE_BLANK in the code to make it work



import requests       
import numpy as np
from bs4 import BeautifulSoup


temp = more_50_rating.join(links,on = 'movieId',lsuffix='_L',rsuffix='_R',how = 'inner')

def scrapper(imdbId):
    id = str(int(imdbId))
    n_zeroes = 7 - len(id)
    new_id = "0"*n_zeroes + id
    URL = f"https://www.imdb.com/title/tt{new_id}/"
    request_header = {'Content-Type': 'text/html; charset=UTF-8', 
                      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 
                      'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL, headers=request_header)
    soup = BeautifulSoup(response.text)
    soup.find('div', attrs={'class':'ipc-list-card--border-speech ipc-list-card sc-ec6ac3bc-1 lmojnD ipc-list-card--base'})
    return imdb_rating.text if imdb_rating else np.nan

# %%
lst = temp['imdbId'].apply(scrapper)

# %%
# Mention the movieId of the movie which has the highest IMDB rating.

temp.sort_values('avg_rating',ascending=False)
# Out:
#       movieId  movieId_L                                              title  \
# 277       318        318                   Shawshank Redemption, The (1994)
# 659       858        858                              Godfather, The (1972)
# 2226     2959       2959                                  Fight Club (1999)
# 975      1276       1276                              Cool Hand Luke (1967)
# 602       750        750  Dr. Strangelove or: How I Learned to Stop Worr...
# ...       ...        ...                                                ...
# 144       172        172                             Johnny Mnemonic (1995)
# 145       173        173                                 Judge Dredd (1995)
# 376       432        432  City Slickers II: The Legend of Curly's Gold (...
# 379       435        435                                   Coneheads (1993)
# 2029     2701       2701                              Wild Wild West (1999)
#
#                             genres  rating  avg_rating  movieId_R  imdbId  \
# 277                    Crime|Drama     317    4.429022        360  110093
# 659                    Crime|Drama     192    4.289062       1129   82340
# 2226   Action|Crime|Drama|Thriller     218    4.272936       3967  249462
# 975                          Drama      57    4.271930       1693  118607
# 602                     Comedy|War      97    4.268041        984  117357
# ...                            ...     ...         ...        ...     ...
# 144         Action|Sci-Fi|Thriller      53    2.679245        204  114781
# 145            Action|Crime|Sci-Fi      62    2.669355        205  114798
# 376       Adventure|Comedy|Western      55    2.645455        495   74102
# 379                  Comedy|Sci-Fi      63    2.420635        499  107613
# 2029  Action|Comedy|Sci-Fi|Western      53    2.207547       3624  184894
#
#        tmdbId
# 277   10879.0
# 659    1103.0
# 2226     71.0
# 975   11831.0
# 602   85328.0
# ...       ...
# 144    3512.0
# 145   52856.0
# 376    5879.0
# 379   31911.0
# 2029   8584.0
#
# [375 rows x 9 columns]

# %%
# Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating.

a = temp[temp['genres'].str.contains('Sci-Fi')]

a.sort_values('avg_rating',ascending=False)
# Out:
#       movieId  movieId_L                                              title  \
# 224       260        260          Star Wars: Episode IV - A New Hope (1977)
# 898      1196       1196  Star Wars: Episode V - The Empire Strikes Back...
# 1939     2571       2571                                 Matrix, The (1999)
# 901      1199       1199                                      Brazil (1985)
# 4909     7361       7361       Eternal Sunshine of the Spotless Mind (2004)
# ...       ...        ...                                                ...
# 559       673        673                                   Space Jam (1996)
# 144       172        172                             Johnny Mnemonic (1995)
# 145       173        173                                 Judge Dredd (1995)
# 379       435        435                                   Coneheads (1993)
# 2029     2701       2701                              Wild Wild West (1999)
#
#                                                  genres  rating  avg_rating  \
# 224                             Action|Adventure|Sci-Fi     251    4.231076
# 898                             Action|Adventure|Sci-Fi     211    4.215640
# 1939                             Action|Sci-Fi|Thriller     278    4.192446
# 901                                      Fantasy|Sci-Fi      59    4.177966
# 4909                               Drama|Romance|Sci-Fi     131    4.160305
# ...                                                 ...     ...         ...
# 559   Adventure|Animation|Children|Comedy|Fantasy|Sc...      53    2.707547
# 144                              Action|Sci-Fi|Thriller      53    2.679245
# 145                                 Action|Crime|Sci-Fi      62    2.669355
# 379                                       Comedy|Sci-Fi      63    2.420635
# 2029                       Action|Comedy|Sci-Fi|Western      53    2.207547
#
#       movieId_R   imdbId   tmdbId
# 224         300   110932  11450.0
# 898        1593   119896   9413.0
# 1939       3439   103060   1497.0
# 901        1597   118883   8834.0
# 4909      78703  1179794  39545.0
# ...         ...      ...      ...
# 559         888   113596  19004.0
# 144         204   114781   3512.0
# 145         205   114798  52856.0
# 379         499   107613  31911.0
# 2029       3624   184894   8584.0
#
# [71 rows x 9 columns]

# %%
# Out:
#       movieId  movieId_L                                              title  \
# 224       260        260          Star Wars: Episode IV - A New Hope (1977)
# 898      1196       1196  Star Wars: Episode V - The Empire Strikes Back...
# 1939     2571       2571                                 Matrix, The (1999)
# 901      1199       1199                                      Brazil (1985)
# 4909     7361       7361       Eternal Sunshine of the Spotless Mind (2004)
# ...       ...        ...                                                ...
# 559       673        673                                   Space Jam (1996)
# 144       172        172                             Johnny Mnemonic (1995)
# 145       173        173                                 Judge Dredd (1995)
# 379       435        435                                   Coneheads (1993)
# 2029     2701       2701                              Wild Wild West (1999)
#
#                                                  genres  rating  avg_rating  \
# 224                             Action|Adventure|Sci-Fi     251    4.231076
# 898                             Action|Adventure|Sci-Fi     211    4.215640
# 1939                             Action|Sci-Fi|Thriller     278    4.192446
# 901                                      Fantasy|Sci-Fi      59    4.177966
# 4909                               Drama|Romance|Sci-Fi     131    4.160305
# ...                                                 ...     ...         ...
# 559   Adventure|Animation|Children|Comedy|Fantasy|Sc...      53    2.707547
# 144                              Action|Sci-Fi|Thriller      53    2.679245
# 145                                 Action|Crime|Sci-Fi      62    2.669355
# 379                                       Comedy|Sci-Fi      63    2.420635
# 2029                       Action|Comedy|Sci-Fi|Western      53    2.207547
#
#       movieId_R   imdbId   tmdbId
# 224         300   110932  11450.0
# 898        1593   119896   9413.0
# 1939       3439   103060   1497.0
# 901        1597   118883   8834.0
# 4909      78703  1179794  39545.0
# ...         ...      ...      ...
# 559         888   113596  19004.0
# 144         204   114781   3512.0
# 145         205   114798  52856.0
# 379         499   107613  31911.0
# 2029       3624   184894   8584.0
#
# [71 rows x 9 columns]
